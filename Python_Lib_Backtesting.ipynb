# %% [markdown]
# <a href="https://colab.research.google.com/github/jeonjnh/python_stock_backtest/blob/main/Python_Lib_Backtesting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install backtesting
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.5/175.5 kB 1.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for backtesting: filename=Backtesting-0.3.3-py3-none-any.whl size=173916 sha256=3b6642e0e22f7f414a529af2206154facb0ff40b0c65e377a2f700ad2e45faf0
#   Stored in directory: /root/.cache/pip/wheels/e2/30/7f/19cbe31987c6ebdb47f1f510343249066711609e3da2d57176
# Successfully built backtesting
# ...

# %%
# !pip install ta
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ta: filename=ta-0.11.0-py3-none-any.whl size=29413 sha256=24e0f4580e14a33ee2a0fa8a671afdb64e128f3414b36b5f4327e3df65189789
#   Stored in directory: /root/.cache/pip/wheels/5f/67/4f/8a9f252836e053e532c6587a3230bc72a4deb16b03a829610b
# Successfully built ta
# ...

# %%
# !pip install yfinance

# %%
import yfinance as yf
import ta
import pandas as pd
from backtesting import Backtest, Strategy
from backtesting.lib import crossover

# %%
class SMAcross(Strategy):

  n1 = 50 #short term
  n2 = 100 #long term

  def init(self):
    close = self.data.Close
    self.sma1 = self.I(ta.trend.sma_indicator, pd.Series(close), self.n1)
    self.sma2 = self.I(ta.trend.sma_indicator, pd.Series(close), self.n2)

  def next(self):
    if crossover(self.sma1, self.sma2):
      self.buy()
    elif crossover(self.sma2, self.sma1):
      self.sell()

# %%
df = yf.download('BTC-USD', start='2023-06-01')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
bt = Backtest(df, SMAcross, cash=100000, commission=0.002, exclusive_orders=True)

# %%
output = bt.run()

# %%
output
# Out:
# Start                     2023-06-01 00:00:00
# End                       2024-01-08 00:00:00
# Duration                    221 days 00:00:00
# Exposure Time [%]                   32.432432
# Equity Final [$]                119582.314391
# Equity Peak [$]                 121600.837828
# Return [%]                          19.582314
# Buy & Hold Return [%]                67.27637
# Return (Ann.) [%]                   34.182435
# Volatility (Ann.) [%]               23.913918
# Sharpe Ratio                         1.429395
# Sortino Ratio                        3.135635
# Calmar Ratio                         7.018191
# Max. Drawdown [%]                   -4.870548
# Avg. Drawdown [%]                    -2.61296
# Max. Drawdown Duration       24 days 00:00:00
# Avg. Drawdown Duration        9 days 00:00:00
# # Trades                                    1
# Win Rate [%]                            100.0
# Best Trade [%]                      28.664694
# ...

# %%
bt.plot()
# Out:
# /usr/local/lib/python3.10/dist-packages/backtesting/_plotting.py:250: UserWarning: DatetimeFormatter scales now only accept a single format. Using the first provided: '%d %b'
#   formatter=DatetimeTickFormatter(days=['%d %b', '%a %d'],
# /usr/local/lib/python3.10/dist-packages/backtesting/_plotting.py:250: UserWarning: DatetimeFormatter scales now only accept a single format. Using the first provided: '%m/%Y'
#   formatter=DatetimeTickFormatter(days=['%d %b', '%a %d'],
# /usr/local/lib/python3.10/dist-packages/backtesting/_plotting.py:659: UserWarning: found multiple competing values for 'toolbar.active_drag' property; using the latest value
#   fig = gridplot(
# /usr/local/lib/python3.10/dist-packages/backtesting/_plotting.py:659: UserWarning: found multiple competing values for 'toolbar.active_scroll' property; using the latest value
#   fig = gridplot(
#   <div id="dbedc4c5-dadd-4af1-b2e3-91fc0c4b1b3d" data-root-id="p1360" style="display: contents;"></div>
# ...

# %%
optim = bt.optimize(n1 = range(50,160,10),
                    n2 = range(50,160,10),
                    constraint= lambda x: x.n2 - x.n1 > 20,
                    maximize= 'Return [%]')

bt.plot()
# Out:
# Backtest.optimize:   0%|          | 0/2 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/backtesting/_plotting.py:250: UserWarning: DatetimeFormatter scales now only accept a single format. Using the first provided: '%d %b'
#   formatter=DatetimeTickFormatter(days=['%d %b', '%a %d'],
# /usr/local/lib/python3.10/dist-packages/backtesting/_plotting.py:250: UserWarning: DatetimeFormatter scales now only accept a single format. Using the first provided: '%m/%Y'
#   formatter=DatetimeTickFormatter(days=['%d %b', '%a %d'],
# /usr/local/lib/python3.10/dist-packages/backtesting/_plotting.py:659: UserWarning: found multiple competing values for 'toolbar.active_drag' property; using the latest value
#   fig = gridplot(
# /usr/local/lib/python3.10/dist-packages/backtesting/_plotting.py:659: UserWarning: found multiple competing values for 'toolbar.active_scroll' property; using the latest value
#   fig = gridplot(
# ...

# %%
optim
# Out:
# Start                     2023-06-01 00:00:00
# End                       2024-01-08 00:00:00
# Duration                    221 days 00:00:00
# Exposure Time [%]                   32.432432
# Equity Final [$]                119582.314391
# Equity Peak [$]                 121600.837828
# Return [%]                          19.582314
# Buy & Hold Return [%]                67.27637
# Return (Ann.) [%]                   34.182435
# Volatility (Ann.) [%]               23.913918
# Sharpe Ratio                         1.429395
# Sortino Ratio                        3.135635
# Calmar Ratio                         7.018191
# Max. Drawdown [%]                   -4.870548
# Avg. Drawdown [%]                    -2.61296
# Max. Drawdown Duration       24 days 00:00:00
# Avg. Drawdown Duration        9 days 00:00:00
# # Trades                                    1
# Win Rate [%]                            100.0
# Best Trade [%]                      28.664694
# ...
